# %% [markdown]
# # This is my notebook on Chapter 5 from Wooldridge
# ### I did 4 computer exercises

# %%
import wooldridge
import statsmodels.formula.api as smf
import statsmodels.api as sm
import numpy as np
import pandas as pd
from scipy import stats
import plotly.express as px

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Task 1

# %%
data = wooldridge.data('WAGE1')

# %%
model = smf.ols(data=data, formula='wage ~ educ + exper + tenure')
fitted = model.fit()
fitted.rsquared
# Out:
# 0.3064224368841789

# %%
model_log = smf.ols(data=data, formula='np.log(wage) ~ educ + exper + tenure')
fitted_log = model_log.fit()
fitted_log.rsquared
# Out:
# 0.3160133195452939

# %%
residuals, residuals_log = fitted.resid, fitted_log.resid
total = pd.concat([residuals, residuals_log], keys=['level', 'log'], names=['model', 'id'])
df = pd.DataFrame(total).reset_index().rename(columns={0: 'residuals'})
df.head(1)
# Out:
#    model  id  residuals
# 0  level   0   -0.66056

# %%
fig = px.histogram(data_frame=df, x='residuals', color='model', marginal="box",
                   barmode='overlay', opacity=.7, nbins=250)
fig.show()
# Out:
# <div>                            <div id="10e8a788-4162-46a1-8f31-bbfb69bf5870" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("10e8a788-4162-46a1-8f31-bbfb69bf5870")) {                    Plotly.newPlot(                        "10e8a788-4162-46a1-8f31-bbfb69bf5870",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"model=level<br>residuals=%{x}<br>count=%{y}<extra></extra>","legendgroup":"level","marker":{"color":"#636efa","opacity":0.7,"pattern":{"shape":""}},"name":"level","nbinsx":250,"offsetgroup":"level","orientation":"v","showlegend":true,"x":[-0.6605600403550347,-1.9048526924502092,-0.760559944987603,-1.6414467868948446,0.49024028087675564,0.4840888827691394,1.8213902848157932,0.06565047831507709,-1.9727481768100645,6.824217908721758,-0.9779596930916368,3.1491705180989236,4.120061693658169,0.2752367251367449,14.653599925569932,10.306540415317535,2.9617588332707783,3.6660702571473127,-1.0052598205224221,-1.6346805777498528,1.6423448251271289,1.3168150453719738,-2.105179844302132,-4.0211332097899835,0.10340766715980187,2.274469673124017,-0.869127247927679,5.096768660532123,5.718073245946948,0.9606899657269796,6.127071694326672,-1.9037983966929453,1.7004585432182058,0.02097143936456458,0.29813529793619686,-3.609250286373367,0.484449426597962,0.5766035248082289,-3.087600614613546,1.689419313795522,3.428135412377115,4.392020384631577,-1.3702084154598957,-2.7523830917515593,0.5433797591875607,4.940975789859385,-1.4692554024881228,-2.5276059078833395,-2.4023689853203245,-1.9192073195153987,-3.0869573272996433,1.483738285754372,-0.4962820179921419,0.34389683625525347,-1.85952501092717,-2.928759728221131,-3.5023143106200822,7.790600538603282,12.18849743113186,-2.487082757620807,2.517235205673936,5.092621167619555,0.9747122525746263,0.30267044487111816,1.5583624783432652,9.99321696414533,-1.294157475171036,4.618860088809951,-2.070444646227161,-2.7204018319570817,-1.0677247560137264,5.052019489397544,-1.1387671618625284,-7.606770402080244,-0.7212226083034521,3.2339357484386646,-0.9403525172838352,-1.4287937570719293,1.5102105071533458,-1.059050254306804,0.6442365434997677,-2.296993349570595,-0.3062738226311157,1.3524342141038543,-1.2874203903828514,-1.853065687023717,-1.3775992446302467,2.695326152260442,2.97498627558522,1.7545387583542276,0.26678869811789596,-1.2478340342999985,-1.3371854914519137,0.4504749318523711,1.926527299344989,0.888329705034848,-1.436150557391482,4.361699896175523,-1.7130110027867316,-0.8818645304024262,-2.131390076869949,-0.8775992446302467,-2.627952962938565,2.4593633835528985,8.145966704376118,-0.01528193172259762,6.840445520525202,-0.1194155850899623,-2.812463896448678,2.33395225273357,-3.3823832061924772,12.191800840406632,0.4433110542072525,0.26213123752976486,-4.758278849711363,0.297991367773633,-2.124473701232076,-1.1697598049539328,-2.615046985107944,-1.6874136602297787,-1.9246539254627706,-0.9721340673159018,-3.1340806892706183,-1.7626919890753756,-4.88621406519472,-1.1682841908076487,1.0510555255347533,-6.189570335271168,-1.0692619942156414,0.82443669000725,0.4365391979221265,-1.4468339619242077,-2.0364115766397752,-0.9499179275211964,-0.08292020567973424,-2.1765435693529396,-1.7835702277723033,2.580432136655779,2.353070967778764,1.999762192286422,0.3401116100527535,3.5404750844402617,-0.09920762469118038,0.8144915172953828,-1.2254947003798722,-3.2949574626168143,-1.183934398523291,-1.184445678818915,3.5461603116081672,-6.0723843568306854,-0.24964825709331784,-0.810580686204478,-0.5941421130546418,1.1600946183346528,-1.5980624078492571,3.238769291702953,-0.1477246797197811,2.8837379042846454,-0.4665775600567663,-1.7950689341834867,-0.3092554358667239,-0.009255245131860601,1.6143391628899577,-1.541877990423016,0.28168084696054585, ...

# %% [markdown]
# As we can see, residuals are more normally distributed in log-level model. In level-level equation residuals are right-skewed and more spread out.

# %% [markdown]
# ## Task 2

# %%
data = wooldridge.data('GPA2')
FIRST, ALL = 2070, data.shape[0]
data.shape
# Out:
# (4137, 12)

# %%
model = smf.ols(data=data.iloc[:, :], formula='colgpa ~ hsperc + sat')
fitted = model.fit()
se1 = fitted.bse['hsperc']
se1
# Out:
# 0.0005494660278445033

# %%
model = smf.ols(data=data.iloc[:FIRST, :], formula='colgpa ~ hsperc + sat')
fitted = model.fit()
se2 = fitted.bse['hsperc']
se2
# Out:
# 0.0007185234883026612

# %%
se2 / se1, np.sqrt(ALL / FIRST)
# Out:
# (1.3076759105951508, 1.4137010732957944)

# %% [markdown]
# ## Task 3

# %% [markdown]
# In this task I would test motheduc + fatheduc significance, using Lagrange Multiplier.

# %%
data = wooldridge.data('BWGHT').dropna(axis=0).reset_index()
model = smf.ols(data=data, formula='bwght ~ cigs + parity + faminc')
fitted = model.fit()
residuals = fitted.resid

# %%
LM_model = sm.OLS(residuals, data[['cigs', 'parity', 'faminc', 'motheduc', 'fatheduc']])
LM_fitted = LM_model.fit()
LM = LM_fitted.nobs * LM_fitted.rsquared
LM
# Out:
# 2.8176100483733233

# %%
critical = stats.chi2.ppf(0.95, 2)
critical
# Out:
# 5.991464547107979

# %%
p_value = 1 - stats.chi2.cdf(LM, 2)
p_value
# Out:
# 0.24443520285554854

# %% [markdown]
# We see, that LM-statistics is around $2.817$, but the critical value for $\chi^2_{2}$ is 6. So we cannot reject the $H_0$ hypothesis (motheduc and fatheduc are jointly significant). The p_value for this test is $\approx 0.25$.

# %% [markdown]
# ## Task 4

# %% [markdown]
# In this task, I would compare skewness of distribution of some variable.

# %%
data = wooldridge.data('401KSUBS')
data = data[data['fsize'] == 1]
data.shape
# Out:
# (2017, 11)

# %%
inc = data.inc.reset_index(drop=True)
log_inc = np.log(inc)
inc = (inc - inc.mean()) / inc.std()
inc_skew = (inc ** 3).sum() / 2016
inc_skew, stats.skew(inc)
# Out:
# (1.863182464872014, 1.863644506407914)

# %%
log_inc = (log_inc - log_inc.mean()) / log_inc.std()
log_inc_skew = (log_inc ** 3).sum() / 2016
log_inc_skew, stats.skew(log_inc)
# Out:
# (0.3607819431388949, 0.3608714116940555)

# %%
incs = pd.concat([inc, log_inc], keys=['inc', 'log(inc)']).reset_index()
incs
fig = px.histogram(data_frame=incs, x='inc', color='level_0', marginal="box",
                   barmode='overlay', opacity=.7, nbins=150)
fig.show()
# Out:
# <div>                            <div id="3473de7b-6e47-4aef-80a3-fe73fe77d571" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("